# %%
#sum of 2 digit 
firstNum = 11
secondNum = 22
sum = firstNum + secondNum
print(sum)
# Out:
# 33

# %%
# subtract of 2 digits
firstNum = 5
secondNum = 1
diff = firstNum - secondNum
print (diff)
# Out:
# 4
